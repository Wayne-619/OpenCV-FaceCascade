# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)

# %%
import cv2
import numpy
from google.colab.patches import cv2_imshow 
from google.colab import files

# %%
# 上傳檔案至colab
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03f50199-e870-4fb5-a94c-506e404717d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03f50199-e870-4fb5-a94c-506e404717d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5566.jpg to 5566.jpg

# %%
# 讀取影像檔案 cv2.imread('檔案存放路徑',附加設定)
img = cv2.imread('/content/5566.jpg')

# %%
# 顯示影像 cv2_imshow('視窗名稱','變數名稱',附加設定)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x327 at 0x7F0B4EF71D10>

# %%
# opencv 內建分類模型存放路徑
casc_path = cv2.data.haarcascades+"haarcascade_frontalface_default.xml"

# 建立偵測物件 cv2.CascadeClassifier(模型存放路徑)
face_casc = cv2.CascadeClassifier(casc_path)

# %%
# 使用物件 detectMultiScale 偵測臉部
# 名稱.detectMultiScale('圖片物件',搜索框大小,最小鄰居認定標準,圖檔最小尺寸,邊緣處理方式)
faces = face_casc.detectMultiScale(img,
                    scaleFactor=1.1,
                    minNeighbors=5,
                    minSize=(30,30),
                    flags = cv2.CASCADE_SCALE_IMAGE)

# %%
# 顯示偵測到幾張人臉
print(len(faces))
# 人臉座標
print(faces[0])
# Out:
# 4
# [239  50  67  67]

# %%
print(faces[1])
# Out:
# [99 71 63 63]

# %%
#用cv2.rectangle 框出人臉 
cv2.rectangle(img,(faces[0][0],faces[0][1]),
       (faces[0][0]+faces[0][2],faces[0][1]+faces[0][3]),
       (0,0,255),2)
# Out:
# array([[[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [243, 230, 244],
#         [243, 230, 244],
#         [243, 230, 244]],
#
#        [[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [244, 232, 244],
#         [244, 232, 244],
#         [244, 232, 244]],
#
#        [[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [244, 232, 244],
#         [244, 232, 244],
#         [245, 233, 245]],
#
#        ...,
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [237, 226, 234],
#         [242, 231, 239],
#         [248, 235, 243]],
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [240, 229, 237],
#         [243, 232, 240],
#         [249, 236, 244]],
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [241, 230, 240],
#         [242, 231, 241],
#         [249, 235, 246]]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x327 at 0x7F0B4F075950>

# %%
# 找出所有人臉並框出
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x327 at 0x7F0B4EF80250>

# %%
img.shape[0]
# Out:
# 327

# %%
img.shape[1]
# Out:
# 500

# %%
#在圖片上註記想要的文字
temp = "OpenCV find "+str(len(faces))+" face!"

# 原始檔案大小
img_h = img.shape[0]
img_w = img.shape[1]

cv2.putText(img,temp,(25,img_h-15),cv2.FONT_HERSHEY_PLAIN,
  1, (0, 0, 255), 1, cv2.LINE_AA)
cv2.putText(img,author,(250,img_h-15),cv2.FONT_HERSHEY_PLAIN,
  1, (255, 0, 0), 1, cv2.LINE_AA)
# Out:
# array([[[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [243, 230, 244],
#         [243, 230, 244],
#         [243, 230, 244]],
#
#        [[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [244, 232, 244],
#         [244, 232, 244],
#         [244, 232, 244]],
#
#        [[255, 244, 254],
#         [255, 244, 254],
#         [254, 243, 253],
#         ...,
#         [244, 232, 244],
#         [244, 232, 244],
#         [245, 233, 245]],
#
#        ...,
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [237, 226, 234],
#         [242, 231, 239],
#         [248, 235, 243]],
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [240, 229, 237],
#         [243, 232, 240],
#         [249, 236, 244]],
#
#        [[255, 244, 252],
#         [255, 244, 252],
#         [255, 244, 252],
#         ...,
#         [241, 230, 240],
#         [242, 231, 241],
#         [249, 235, 246]]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x327 at 0x7F0B4EF89810>

# %%
# 座標
x = faces[1][0]
y = faces[1][1]
w = faces[1][2]
h = faces[1][3]

# %%
# 截取人臉
face1 = img[y:y+h,x:x+w]
cv2_imshow(face1)
# Out:
# <PIL.Image.Image image mode=RGB size=63x63 at 0x7F0B4EF71D10>

# %%
# 印出所有人臉
for (x,y,w,h) in faces:
  face_all = img[y:y+h,x:x+w]
  cv2_imshow(face_all)
# Out:
# <PIL.Image.Image image mode=RGB size=67x67 at 0x7F0B4EF67C50>
# <PIL.Image.Image image mode=RGB size=63x63 at 0x7F0B4EF67C10>
# <PIL.Image.Image image mode=RGB size=67x67 at 0x7F0B4EF67890>
# <PIL.Image.Image image mode=RGB size=74x74 at 0x7F0B4EF67C10>
